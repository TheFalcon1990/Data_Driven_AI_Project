# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from os import walk
import os
import glob
import tensorflow as tf

# %%
for i in range(1,9):
    folder_path = f'./Stage {i}'
    output_folder = f'Resized_Images/Resized_Stage{i}'
    os.makedirs(output_folder, exist_ok=True)
    j = 1
# Loop through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')): 
        # Read the image
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)

            # Resize the image to 150x150
            resized_image = cv2.resize(image, (150, 150))

            # Save the resized image in the output folder
            output_path = os.path.join(output_folder, f'Stage_{i}_u2261333_({j}).jpg')
            cv2.imwrite(output_path, resized_image)

            print(f"Resized and saved {filename}")
            j += 1
# Out:
# Resized and saved Stage_1 (1).jpg
# Resized and saved Stage_1 (10).jpg
# Resized and saved Stage_1 (2).jpg
# Resized and saved Stage_1 (3).jpg
# Resized and saved Stage_1 (4).jpg
# Resized and saved Stage_1 (5).jpg
# Resized and saved Stage_1 (6).jpg
# Resized and saved Stage_1 (7).jpg
# Resized and saved Stage_1 (8).jpg
# Resized and saved Stage_1 (9).jpg
# Resized and saved Stage_2 (1).jpg
# Resized and saved Stage_2 (10).jpg
# Resized and saved Stage_2 (2).jpg
# Resized and saved Stage_2 (3).jpg
# Resized and saved Stage_2 (4).jpg
# Resized and saved Stage_2 (5).jpg
# Resized and saved Stage_2 (6).jpg
# Resized and saved Stage_2 (7).jpg
# Resized and saved Stage_2 (8).jpg
# Resized and saved Stage_2 (9).jpg
# Resized and saved Stage_3 (1).jpg
# Resized and saved Stage_3 (10).jpg
# Resized and saved Stage_3 (2).jpg
# Resized and saved Stage_3 (3).jpg
# Resized and saved Stage_3 (4).jpg
# Resized and saved Stage_3 (5).jpg
# Resized and saved Stage_3 (6).jpg
# Resized and saved Stage_3 (7).jpg
# Resized and saved Stage_3 (8).jpg
# Resized and saved Stage_3 (9).jpg
# Resized and saved Stage_5 (1).jpg
# Resized and saved Stage_5 (10).jpg
# Resized and saved Stage_5 (2).jpg
# Resized and saved Stage_5 (3).jpg
# Resized and saved Stage_5 (4).jpg
# Resized and saved Stage_5 (5).jpg
# Resized and saved Stage_5 (6).jpg
# Resized and saved Stage_5 (7).jpg
# Resized and saved Stage_5 (8).jpg
# Resized and saved Stage_5 (9).jpg
# Resized and saved Stage_5 (1).jpg
# Resized and saved Stage_5 (10).jpg
# Resized and saved Stage_5 (2).jpg
# Resized and saved Stage_5 (3).jpg
# Resized and saved Stage_5 (4).jpg
# Resized and saved Stage_5 (5).jpg
# Resized and saved Stage_5 (6).jpg
# Resized and saved Stage_5 (7).jpg
# Resized and saved Stage_5 (8).jpg
# Resized and saved Stage_5 (9).jpg
# Resized and saved Stage_6 (1).jpg
# Resized and saved Stage_6 (10).jpg
# Resized and saved Stage_6 (2).jpg
# Resized and saved Stage_6 (3).jpg
# Resized and saved Stage_6 (4).jpg
# Resized and saved Stage_6 (5).jpg
# Resized and saved Stage_6 (6).jpg
# Resized and saved Stage_6 (7).jpg
# Resized and saved Stage_6 (8).jpg
# Resized and saved Stage_6 (9).jpg
# Resized and saved Stage_7 (1).jpg
# Resized and saved Stage_7 (10).jpg
# Resized and saved Stage_7 (2).jpg
# Resized and saved Stage_7 (3).jpg
# Resized and saved Stage_7 (4).jpg
# Resized and saved Stage_7 (5).jpg
# Resized and saved Stage_7 (6).jpg
# Resized and saved Stage_7 (7).jpg
# Resized and saved Stage_7 (8).jpg
# Resized and saved Stage_7 (9).jpg
# Resized and saved Stage 8 (1).jpg
# Resized and saved Stage 8 (10).jpg
# Resized and saved Stage 8 (2).jpg
# Resized and saved Stage 8 (3).jpg
# Resized and saved Stage 8 (4).jpg
# Resized and saved Stage 8 (5).jpg
# Resized and saved Stage 8 (6).jpg
# Resized and saved Stage 8 (7).jpg
# Resized and saved Stage 8 (8).jpg
# Resized and saved Stage 8 (9).jpg
